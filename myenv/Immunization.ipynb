# %%
import pandas as pd
import glob

file_paths = glob.glob("./Datasets/*.json")
dfs = [pd.read_json(file_path) for file_path in file_paths]
combined_df = pd.concat(dfs, ignore_index=True)

# %%
entries=pd.json_normalize(combined_df.entry)

# %%
Encounter_data = entries[entries["resource.resourceType"]=="Encounter"]
Immunization_data = entries[entries["resource.resourceType"]=="Immunization"]

# %%
Immunization_data.columns
# Out:
# Index(['fullUrl', 'resource.id', 'resource.text.status', 'resource.text.div',
#        'resource.extension', 'resource.identifier', 'resource.name',
#        'resource.telecom', 'resource.gender', 'resource.birthDate',
#        'resource.address', 'resource.maritalStatus.coding',
#        'resource.multipleBirthBoolean', 'resource.photo',
#        'resource.resourceType', 'resource.status', 'resource.class.code',
#        'resource.type', 'resource.patient.reference', 'resource.period.start',
#        'resource.period.end', 'resource.clinicalStatus',
#        'resource.verificationStatus', 'resource.code.coding',
#        'resource.subject.reference', 'resource.context.reference',
#        'resource.onsetDateTime', 'resource.abatementDateTime',
#        'resource.encounter.reference', 'resource.effectiveDateTime',
#        'resource.valueQuantity.value', 'resource.valueQuantity.unit',
#        'resource.valueQuantity.system', 'resource.valueQuantity.code',
#        'resource.component', 'resource.date', 'resource.vaccineCode.coding',
#        'resource.wasNotGiven', 'resource.primarySource', 'resource.category',
#        'resource.activity', 'resource.code.text',
#        'resource.performedPeriod.start', 'resource.performedPeriod.end',
#        'resource.issued', 'resource.performer', 'resource.result',
#        'resource.performedDateTime', 'resource.addresses',
#        'resource.reason.coding', 'resource.stage.coding',
#        'resource.medicationCodeableConcept.coding', 'resource.dateWritten',
#        'resource.reasonReference', 'resource.dosageInstruction',
#        'resource.reasonReference.reference', 'resource.deceasedDateTime',
#        'resource.valueCodeableConcept.coding',
#        'resource.dispenseRequest.numberOfRepeatsAllowed',
#        'resource.dispenseRequest.quantity.value',
#        'resource.dispenseRequest.quantity.unit',
#        'resource.dispenseRequest.expectedSupplyDuration.value',
#        'resource.dispenseRequest.expectedSupplyDuration.unit',
#        'resource.dispenseRequest.expectedSupplyDuration.system',
#        'resource.dispenseRequest.expectedSupplyDuration.code',
#        'resource.criticality', 'resource.assertedDate',
#        'resource.multipleBirthInteger'],
#       dtype='object')

# %%
encounter_ref = Encounter_data[['fullUrl','resource.patient.reference']]

# %%
merged_data = pd.merge(
    encounter_ref,
    Immunization_data,
    
    left_on="fullUrl",  # Assuming patient IDs are under "resource.id" in encounter data
    right_on="resource.encounter.reference",  # Assuming patient IDs are in a column named "Patient id" in the CSV file
    how="right" , # Use "left" join to keep all encounter records
)
merged_data
# Out:
#                                          fullUrl_x  \
# 0    urn:uuid:2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 1    urn:uuid:f5b01614-f569-4e9e-b482-cc0231a7c20a
# 2    urn:uuid:f5b01614-f569-4e9e-b482-cc0231a7c20a
# 3    urn:uuid:1460d856-b01a-4c3b-b8c7-07fd86cac5fe
# 4    urn:uuid:df35b4c3-93ee-4f2c-b85e-af2f110f6d30
# ..                                             ...
# 227  urn:uuid:01e1e451-d7c5-4876-b4e7-d499eaada844
# 228  urn:uuid:638fee81-9b8f-4896-8536-407e34db67c0
# 229  urn:uuid:638fee81-9b8f-4896-8536-407e34db67c0
# 230  urn:uuid:ba8b290e-98ba-4c40-90bd-a0a500b339b8
# 231  urn:uuid:5b6a51a4-5c13-42b0-b885-8936c9cc36f3
#
#                       resource.patient.reference_x fullUrl_y resource.id  \
# 0    urn:uuid:80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN         NaN
# 1    urn:uuid:80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN         NaN
# 2    urn:uuid:80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN         NaN
# 3    urn:uuid:80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN         NaN
# 4    urn:uuid:80bb41d3-ebb4-42e6-b087-6ee89b0463a9       NaN         NaN
# ..                                             ...       ...         ...
# 227  urn:uuid:aa3973d9-b64f-4a36-8cb6-f2719080b52f       NaN         NaN
# 228  urn:uuid:aa3973d9-b64f-4a36-8cb6-f2719080b52f       NaN         NaN
# 229  urn:uuid:aa3973d9-b64f-4a36-8cb6-f2719080b52f       NaN         NaN
# 230  urn:uuid:aa3973d9-b64f-4a36-8cb6-f2719080b52f       NaN         NaN
# 231  urn:uuid:aa3973d9-b64f-4a36-8cb6-f2719080b52f       NaN         NaN
#
#     resource.text.status resource.text.div resource.extension  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ..                   ...               ...                ...
# 227                  NaN               NaN                NaN
# 228                  NaN               NaN                NaN
# 229                  NaN               NaN                NaN
# 230                  NaN               NaN                NaN
# 231                  NaN               NaN                NaN
#
#     resource.identifier resource.name resource.telecom  ...  \
# 0                   NaN           NaN              NaN  ...
# 1                   NaN           NaN              NaN  ...
# 2                   NaN           NaN              NaN  ...
# 3                   NaN           NaN              NaN  ...
# 4                   NaN           NaN              NaN  ...
# ..                  ...           ...              ...  ...
# 227                 NaN           NaN              NaN  ...
# 228                 NaN           NaN              NaN  ...
# 229                 NaN           NaN              NaN  ...
# 230                 NaN           NaN              NaN  ...
# 231                 NaN           NaN              NaN  ...
#
#     resource.dispenseRequest.numberOfRepeatsAllowed  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 227                                             NaN
# 228                                             NaN
# 229                                             NaN
# 230                                             NaN
# 231                                             NaN
#
#     resource.dispenseRequest.quantity.value  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 227                                     NaN
# 228                                     NaN
# 229                                     NaN
# 230                                     NaN
# 231                                     NaN
#
#     resource.dispenseRequest.quantity.unit  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 227                                    NaN
# 228                                    NaN
# 229                                    NaN
# 230                                    NaN
# 231                                    NaN
#
#     resource.dispenseRequest.expectedSupplyDuration.value  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
#
#     resource.dispenseRequest.expectedSupplyDuration.unit  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
#
#     resource.dispenseRequest.expectedSupplyDuration.system  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
#
#     resource.dispenseRequest.expectedSupplyDuration.code resource.criticality  \
# 0                                                  NaN                    NaN
# 1                                                  NaN                    NaN
# 2                                                  NaN                    NaN
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# ..                                                 ...                    ...
# 227                                                NaN                    NaN
# 228                                                NaN                    NaN
# 229                                                NaN                    NaN
# 230                                                NaN                    NaN
# 231                                                NaN                    NaN
#
#     resource.assertedDate resource.multipleBirthInteger
# 0                     NaN                           NaN
# 1                     NaN                           NaN
# 2                     NaN                           NaN
# 3                     NaN                           NaN
# 4                     NaN                           NaN
# ..                    ...                           ...
# 227                   NaN                           NaN
# 228                   NaN                           NaN
# 229                   NaN                           NaN
# 230                   NaN                           NaN
# 231                   NaN                           NaN
#
# [232 rows x 70 columns]

# %%
Immunization_name=pd.json_normalize(merged_data['resource.vaccineCode.coding'].explode())['display']

# %%
# Step 6: Extract the Necessary Fields and Create the Final DataFrame
Immunization_output = pd.DataFrame({
    'Status': merged_data['resource.status'],
    'Immunization_data':merged_data['resource.date'],
    "Immunization Name":Immunization_name,
    "Encounter_id":merged_data['resource.encounter.reference'].str.replace('urn:uuid:', ''),
    'patient_id': merged_data['resource.patient.reference_x'].str.replace('urn:uuid:', ''),
})
Immunization_output
# Out:
#         Status          Immunization_data  \
# 0    completed  2010-05-12T10:33:51-04:00
# 1    completed  2011-07-02T14:56:51-04:00
# 2    completed  2011-07-02T14:56:51-04:00
# 3    completed  2012-06-03T09:20:31-04:00
# 4    completed  2013-05-24T07:52:53-04:00
# ..         ...                        ...
# 227  completed  2014-09-02T13:05:08-04:00
# 228  completed  2015-05-15T04:15:28-04:00
# 229  completed  2015-05-15T04:15:28-04:00
# 230  completed  2016-02-04T22:15:59-05:00
# 231  completed  2017-01-25T15:04:04-05:00
#
#                                      Immunization Name  \
# 0    Influenza, seasonal, injectable, preservative ...
# 1    Influenza, seasonal, injectable, preservative ...
# 2                         Td (adult) preservative free
# 3    Influenza, seasonal, injectable, preservative ...
# 4    Influenza, seasonal, injectable, preservative ...
# ..                                                 ...
# 227                                             zoster
# 228  Influenza, seasonal, injectable, preservative ...
# 229                       Td (adult) preservative free
# 230  Influenza, seasonal, injectable, preservative ...
# 231  Influenza, seasonal, injectable, preservative ...
#
#                              Encounter_id  \
# 0    2c722ad1-5a59-4f6a-90cc-c55f86bbd9c6
# 1    f5b01614-f569-4e9e-b482-cc0231a7c20a
# 2    f5b01614-f569-4e9e-b482-cc0231a7c20a
# 3    1460d856-b01a-4c3b-b8c7-07fd86cac5fe
# 4    df35b4c3-93ee-4f2c-b85e-af2f110f6d30
# ..                                    ...
# 227  01e1e451-d7c5-4876-b4e7-d499eaada844
# 228  638fee81-9b8f-4896-8536-407e34db67c0
# 229  638fee81-9b8f-4896-8536-407e34db67c0
# 230  ba8b290e-98ba-4c40-90bd-a0a500b339b8
# 231  5b6a51a4-5c13-42b0-b885-8936c9cc36f3
#
#                                patient_id
# 0    80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 1    80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 2    80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 3    80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# 4    80bb41d3-ebb4-42e6-b087-6ee89b0463a9
# ..                                    ...
# 227  aa3973d9-b64f-4a36-8cb6-f2719080b52f
# 228  aa3973d9-b64f-4a36-8cb6-f2719080b52f
# 229  aa3973d9-b64f-4a36-8cb6-f2719080b52f
# 230  aa3973d9-b64f-4a36-8cb6-f2719080b52f
# 231  aa3973d9-b64f-4a36-8cb6-f2719080b52f
#
# [232 rows x 5 columns]
