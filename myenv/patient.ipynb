# %%
import os
import json
import pandas as pd
from datetime import datetime

# Directory containing the JSON files
directory = './Datasets/'

# %%
data = pd.read_json('./Datasets/000e7fac-5ea9-404d-8434-1229c16c29b0.json')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          75 non-null     object
#  1   entry         75 non-null     object
#  2   resourceType  75 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
data['entry'][1]
# Out:
# {'fullUrl': 'urn:uuid:a3e3bd43-ef3c-48fd-9851-5302d1aa84c6',
#  'resource': {'id': 'a3e3bd43-ef3c-48fd-9851-5302d1aa84c6',
#   'status': 'finished',
#   'class': {'code': 'ambulatory'},
#   'type': [{'coding': [{'system': 'http://snomed.info/sct',
#       'code': '185345009'}],
#     'text': 'Encounter for symptom'}],
#   'patient': {'reference': 'urn:uuid:65d12976-9588-4cfa-a795-216302a2ece9'},
#   'period': {'start': '2010-07-31T13:21:25-04:00',
#    'end': '2010-07-31T13:21:25-04:00'},
#   'reason': {'coding': [{'system': 'http://snomed.info/sct',
#      'code': '43878008',
#      'display': 'Streptococcal sore throat (disorder)'}]},
#   'resourceType': 'Encounter'}}

# %%
pd.json_normalize(data['entry'][0])
# Out:
#                                          fullUrl  \
# 0  urn:uuid:65d12976-9588-4cfa-a795-216302a2ece9
#
#                             resource.id resource.text.status  \
# 0  65d12976-9588-4cfa-a795-216302a2ece9            generated
#
#                                    resource.text.div  \
# 0  <div>Generated by <a href="https://github.com/...
#
#                                   resource.extension  \
# 0  [{'url': 'http://hl7.org/fhir/StructureDefinit...
#
#                                  resource.identifier  \
# 0  [{'system': 'https://github.com/synthetichealt...
#
#                                        resource.name  \
# 0  [{'use': 'official', 'family': 'Stracke702', '...
#
#                                     resource.telecom resource.gender  \
# 0  [{'extension': [{'url': 'http://standardhealth...          female
#
#   resource.birthDate                                   resource.address  \
# 0         1997-06-23  [{'extension': [{'extension': [{'url': 'latitu...
#
#    resource.multipleBirthBoolean  \
# 0                          False
#
#                                       resource.photo resource.resourceType
# 0  [{'contentType': 'image/png', 'data': 'iVBORw0...               Patient

# %%
# List to hold all patient details
patients = []

# Iterate through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.json'):
        filepath = os.path.join(directory, filename)
        
        # Open and load the JSON file
        with open(filepath, 'r') as file:
            data = json.load(file)
            
            # Extract patient details from the current JSON file
            for entry in data.get('entry', []):
                # print(entry['re'])
                resource = entry.get('resource', {})
                name_info = resource.get('name', [{}])[0]
                address_info = resource.get('address', [{}])[0]
                marital_status_info = resource.get('maritalStatus', {}).get('coding', [{}])[0]
                            # Extract prefix information
                prefix_info = resource.get('prefix', [{}])[0]
                prefix = prefix_info.get('prefix', '')

                # Determine appropriate prefix based on gender
                gender = resource.get('gender', '').lower()
                if gender == 'male':
                    prefix = "Mr."
                else:
                    prefix = "Mrs."
                def remove_numbers_from_string(s):
                    return ''.join([char for char in s if not char.isdigit()])

                given_names = ' '.join([remove_numbers_from_string(name) for name in name_info.get('given', [])])
                family_name = remove_numbers_from_string(name_info.get('family', ''))
                ethnicity = ""
                race = ""

                for e in resource.get('extension', []):
                    if e.get("valueCodeableConcept"):
                        if e["valueCodeableConcept"].get("text") == "race":
                            race = e["valueCodeableConcept"]["coding"][0].get("display", "")
                        elif e["valueCodeableConcept"].get("text") == "ethnicity":
                            ethnicity = e["valueCodeableConcept"]["coding"][0].get("display", "")
                phone_number = ""
                for telecom in resource.get('telecom', []):
                    if telecom.get('system') == 'phone' and telecom.get('use') == 'home':
                        phone_number = telecom.get('value', '')
                    break
                marital_code = resource.get("maritalStatus", {}).get("coding", [{}])[0].get("code", "")
                if marital_code == "S":
                    marital_status = "Single"
                elif marital_code == "M":
                    marital_status = "Married"
                else:
                    marital_status = "Unknown"
                
                # Concatenate prefix, given names, and family name
                full_name = prefix + ' ' + given_names + ' ' + family_name

                # Create patient dictionary
                patient = {
                    'Patient ID': resource.get('id', ''),
                    'name': full_name,
                    'gender': resource.get('gender', ''),
                    'birth_date': resource.get('birthDate', ''),
                    'marital_status': marital_status,
                    'city': address_info.get('city', ''),
                    'state': address_info.get('state', ''),
                    'race': race,
                    'ethnicity': ethnicity,
                    'Phone_Number':phone_number,
                }

                patients.append(patient)

# Create a DataFrame from the list of patient details
df = pd.DataFrame(patients, columns=['Patient ID','name', 'gender', 'birth_date','Phone_Number','marital_status','race','ethnicity', 'city', 'state'])

# Correct the address concatenation
df['address'] = df['city'] + ', ' + df['state']

# # Add patient ID
# df['Patient ID'] = 
# df["Race"]=race
# Calculate age
def calculate_age(birth_date):
    if birth_date:
        birth_date = datetime.strptime(birth_date, '%Y-%m-%d')
        today = datetime.today()
        age = today.year - birth_date.year 
        return str(age)+' yrs'
    else:
        return None


df['age'] = df['birth_date'].apply(calculate_age)

# Rearrange columns to match the desired order
df = df[['Patient ID', 'name', 'gender', 'age','Phone_Number','race','ethnicity','address', 'marital_status']]

# Convert column names to uppercase and show only the first letter of each word
df.columns = [col.upper()[0] + col[1:].lower() for col in df.columns]


# Save the DataFrame to a CSV file
csv_file = 'patients_data.csv'
df.to_csv(csv_file, index=False)

print(f'CSV file created: {csv_file}')
# Out:
# CSV file created: patients_data.csv

# %%
df=pd.read_csv("patients_data.csv")
df
len(df)
# Out:
# 2446

# %%
df=pd.read_csv("patients_data.csv")
# print(df)
cleaned_data = df.dropna(subset=[col for col in df.columns if col != 'phone_number'])
# Reset the index of the DataFrame
cleaned_data.reset_index(drop=True, inplace=True)

cleaned_data
# Out:
#                               Patient id                      Name  Gender  \
# 0   80bb41d3-ebb4-42e6-b087-6ee89b0463a9       Mrs. Zachary Willms  female
# 1   bb357dc7-2f8a-444e-ba57-8291b6f18bf0         Mrs. Sunny Pouros  female
# 2   c71d235f-9b58-4106-b744-c554da5e13fa         Mr. Sylvia Reilly    male
# 3   509474a0-baf3-48f2-a595-67b6e2b34c87          Mr. Tess DuBuque    male
# 4   f10fd607-58ce-4be6-b1bd-a98898c8e0e5        Mrs. Victor Kuphal  female
# 5   65dfe191-c7ef-4148-8f12-49f832525d4c       Mrs. Destinee Welch  female
# 6   3a268300-21fb-4ef0-b794-02aa0e5a7e5f         Mrs. Robbie Kling  female
# 7   1694897b-912e-401f-a135-aa59857a401e        Mr. Julien Barrows    male
# 8   117335bb-33ff-4897-ac27-af4b3f11135f          Mr. Bart Schaden    male
# 9   a0dcd747-1d40-40fd-8e42-1f9395f034ca          Mrs. Evan Klocko  female
# 10  00d869e2-6793-4ebf-9340-38bf18d223c4       Mrs. Melisa Gerhold  female
# 11  1bd855fa-45c4-4c23-a608-fdeeb3bc2d8b       Mr. Mario Gulgowski    male
# 9    80 yrs   (386) 001-8200 x5002  White   Nonhispanic          Lynn, MA
# 10   31 yrs    936-012-7686 x01564  White   Nonhispanic       Methuen, MA
# 11   92 yrs   (446) 912-8743 x8502  Other  Puerto_rican          Lynn, MA
# 12   62 yrs           533.091.9937  White   Nonhispanic      Abington, MA
# 13   36 yrs           891.889.5056  White   Nonhispanic      Stoneham, MA
# 14   81 yrs         (485) 116-7599  White   Nonhispanic      Brockton, MA
# 15   32 yrs     195.230.2003 x9892  Black   Nonhispanic      Brockton, MA
# 16   53 yrs         (619) 737-6908  Other  Puerto_rican     Haverhill, MA
# 17    9 yrs  (580) 812-0728 x20440  White   Nonhispanic  Southborough, MA
# 18  103 yrs           506.111.6833  White   Nonhispanic     Worcester, MA
# 19   46 yrs      237.167.0269 x694  White   Nonhispanic         Acton, MA
# 20  116 yrs         (223) 369-1024  White   Nonhispanic     Templeton, MA
# 21   69 yrs      940.129.3889 x903  White   Nonhispanic   Springfield, MA
# 22   16 yrs     456-050-1930 x9499  White   Nonhispanic     Worcester, MA
# 23   49 yrs         1-734-978-8625  White   Nonhispanic     Stoughton, MA
# 24   77 yrs    564.380.6900 x16552  White   Nonhispanic      Brewster, MA
# 25   18 yrs      680-431-1926 x154  White   Nonhispanic        Lowell, MA
# 26   41 yrs   (575) 621-7064 x1127  White   Nonhispanic   Hubbardston, MA
# 27   93 yrs           707.709.1861  White   Nonhispanic        Easton, MA
# 28   84 yrs    682-907-8225 x71601  White   Nonhispanic        Lowell, MA
# 29   44 yrs    1-109-767-6386 x585  White   Nonhispanic        Boston, MA
# 30   47 yrs           358.845.4625  White   Nonhispanic        Sharon, MA
# 31   37 yrs           616-811-8945  Other  Puerto_rican          Lynn, MA
# 32   27 yrs         (316) 617-5096  White   Nonhispanic        Newton, MA
# 33   76 yrs    496-882-5625 x30016  Black   Nonhispanic   Southbridge, MA
# 34   34 yrs  (382) 333-7091 x51246  White   Nonhispanic        Newton, MA
# 35  114 yrs           697-104-6654  White   Nonhispanic   Northampton, MA
# 36   42 yrs         (392) 129-8441  White   Nonhispanic     Westfield, MA
# 37   70 yrs   (779) 283-1133 x7121  White   Nonhispanic        Dedham, MA
# 38   98 yrs  (963) 376-1584 x17841  Asian   Nonhispanic   Easthampton, MA
#
#    Marital_status
# 0         Married
# 1          Single
# 2         Married
# 3         Unknown
# 4         Married
# 5         Unknown
# 6         Married
# 7         Unknown
# 8         Married
# 9          Single
# 10        Unknown
# 11        Married
# 12        Married
# 13        Married
# 14        Married
# 15        Unknown
# 16        Married
# 17        Unknown
# 18        Married
# 19         Single
# 20        Married
# 21        Married
# 22        Unknown
# 23        Married
# 24        Married
# 25        Unknown
# 26        Married
# 27        Married
# 28        Married
# 29        Married
# 30        Unknown
# 31        Married
# 32        Unknown
# 33        Married
# 34        Unknown
# 35        Married
# 36         Single
# 37        Married
# 38        Married

# %%
len(cleaned_data)
# Out:
# 39

# %%
# Define the name of the Excel file to save the cleaned data
cleaned_excel_file = 'patient_Details_formated.xlsx'

# Save the cleaned data to an Excel file
cleaned_data.to_excel(cleaned_excel_file, index=False)

# Print a confirmation message
print(f'Cleaned Excel file created: {cleaned_excel_file}')
# Out:
# Cleaned Excel file created: patient_Details_formated.xlsx
